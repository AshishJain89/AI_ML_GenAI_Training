# %% [markdown]
# # Objective
#
# - Illustrate how RAG responses could be improved with self-reflection.
# - Introduce how `langgraph` could be used to compose LLM execution graphs.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Setup

# %% [markdown]
# ## Installation

# %%
# ! pip install -q openai==1.55.3 langchain==0.3.7 langchain-openai==0.2.9 langgraph==0.2.52
# %pip install -q groq openai openai-swarm langchain langchain-openai langchain-groq langchain-experimental langgraph ipykernel

# %pip install -q --upgrade groq langchain langchain-groq langchain-experimental
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports

# %%
import json, os

from groq import Groq
from langchain_groq import ChatGroq
# from langchain_openai import AzureChatOpenAI
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

from langgraph.graph import END, StateGraph, START
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver

from typing import Annotated, List, Sequence
from typing_extensions import TypedDict

from IPython.display import Image, display
from dotenv import load_dotenv

# from swarm import Swarm, Agent
# from langchain import hub

# from langchain_core.tools import tool
# from langchain_experimental.utilities import PythonREPL
# from langchain.agents import create_react_agent, Tool, AgentExecutor
# from langchain_core.messages import HumanMessage, SystemMessage  #, ToolMessage, AIMessage


MODEL_NAME = 'gemma-9b-it'  # 'qwen/qwen3-32b' 'openai/gpt-oss-20b' 
groq_api_key = os.environ.get('GROQ_API_KEY')
load_dotenv()
# Out:
# True

# %%
# with open('config-azure.json') as f:
#     configs = f.read()
# creds = json.loads(configs)

# llm = AzureChatOpenAI(azure_endpoint=creds['AZURE_OPENAI_ENDPOINT'], api_key=creds['AZURE_OPENAI_KEY'], api_version="2024-02-01", model="gpt-4o-mini", temperature=0)
llm_groq = ChatGroq(api_key=groq_api_key, model='gemma2-9b-it')

# %% [markdown]
# # Business Context

# %% [markdown]
# A banking institution wants to implement a robust RAG system that gives accurate, high quality answers to questions from their analysts rooted on financial documents.
#
# In this notebook, we implement a RAG agent that utilizes self-reflection to progressively improve its answer.
#
# To ensure that our focus is on the pattern of self-reflection, we will assume that the appropriate context for a user question is already retrieved from a vector database. This context is presented below.

# %%
financial_statement_context_data = """
Overview and 2023 Highlights
Our mission is to accelerate the world's transition to sustainable energy. We design, develop, manufacture, lease and sell high-performance fully electric vehicles, solar energy generation systems and energy storage products. We also offer maintenance, installation, operation, charging, insurance, financial and other services related to our products. Additionally, we are increasingly focused on products and services based on artificial intelligence, robotics and automation.
In 2023, we produced 1,845,985 consumer vehicles and delivered 1,808,581 consumer vehicles. We are currently focused on increasing vehicle production, capacity and delivery capabilities, reducing costs, improving and developing our vehicles and battery technologies, vertically integrating and localizing our supply chain, improving and further deploying our FSD capabilities, increasing the affordability and efficiency of our vehicles, bringing new products to market and expanding our global infrastructure, including our service and charging infrastructure.
In 2023, we deployed 14.72 GWh of energy storage products and 223 megawatts of solar energy systems. We are currently focused on ramping production of energy storage products, improving our Solar Roof installation capability and efficiency, and increasing market share of retrofit solar energy systems.
In 2023, we recognized total revenues of $96.77 billion, representing an increase of $15.31 billion, compared to the prior year. We continue to ramp production, build new manufacturing capacity and expand our operations to enable increased deliveries and deployments of our products, and invest in research and development to accelerate our AI, software and fleet-based profits for further revenue growth.
In 2023, our net income attributable to common stockholders was $15.00 billion, representing a favorable change of $2.44 billion, compared to the prior year. This included a one-time non-cash tax benefit of $5.93 billion for the release of valuation allowance on certain deferred tax assets. We continue to focus on further cost reductions and operational efficiencies while maximizing delivery volumes.
We ended 2023 with $29.09 billion in cash and cash equivalents and investments, representing an increase of $6.91 billion from the end of 2022. Our cash flows provided by operating activities in 2023 and 2022 were $13.26 billion and $14.72 billion, respectively, representing a decrease of $1.47 billion. Capital expenditures amounted to $8.90 billion in 2023, compared to $7.16 billion in 2022, representing an increase of $1.74 billion. Sustained growth has allowed our business to generally fund itself, and we will continue investing in a number of capital-intensive projects and research and development in upcoming periods.

We are focused on growing our manufacturing capacity, which includes capacity for manufacturing new vehicle models such as our Cybertruck and next generation platform, and ramping all of our production vehicles to their installed production capacities as well as increasing production rate and efficiency at our current factories. The next phase of production growth will depend on the continued ramp at our factories and the introduction of our next generation platform, as well as our ability to add to our available sources of battery cell supply by manufacturing our own cells that we are developing to have high-volume output, lower capital and production costs and longer range. Our goals are to improve vehicle performance, decrease production costs and increase affordability and customer awareness.
These plans are subject to uncertainties inherent in establishing and ramping manufacturing operations, which may be exacerbated by new product and manufacturing technologies we introduce, the number of concurrent international projects, any industry-wide component constraints, labor shortages and any future impact from events outside of our control. For example, during the third quarter of 2023, we experienced a sequential decline in production volumes due to pre-planned shutdowns for upgrades at various factories. Moreover, we have set ambitious technological targets with our plans for battery cells as well as for iterative manufacturing and design improvements for our vehicles with each new factory.
Automotive—Demand, Sales, Deliveries and Infrastructure
Our cost reduction efforts, cost innovation strategies, and additional localized procurement and manufacturing are key to our vehicles’ affordability and have allowed us to competitively price our vehicles. We will also continue to generate demand and brand awareness by improving our vehicles’ performance and functionality, including through products based on artificial intelligence such as Autopilot, FSD Capability, and other software features and delivering new vehicles, such as our Cybertruck. Moreover, we expect to continue to benefit from ongoing electrification of the automotive sector and increasing environmental regulations and initiatives.
However, we operate in a cyclical industry that is sensitive to political and regulatory uncertainty, including with respect to trade and the environment, all of which can be compounded by inflationary pressures, rising energy prices, interest rate fluctuations and the liquidity of enterprise customers. For example, inflationary pressures have increased across the markets in which we operate. In an effort to curb this trend, central banks in developed countries raised interest rates rapidly and substantially, impacting the affordability of vehicle lease and finance arrangements. Further, sales of vehicles in the automotive industry also tend to be cyclical in many markets, which may expose us to increased volatility as we expand and adjust our operations. Moreover, as additional competitors enter the marketplace and help bring the world closer to sustainable transportation, we will have to adjust and continue to execute well to maintain our momentum. Additionally, our suppliers’ liquidity and allocation plans may be affected by current challenges in the North American automotive industry, which could reduce our access to components or result in unfavorable changes to cost. These macroeconomic and industry trends have had, and will likely continue to have, an impact on the pricing of, and order rate for our vehicles, and in turn our operating margin. Changes in government and economic incentives in relation to electric vehicles may also impact our sales. We will continue to adjust accordingly to such developments, and we believe our ongoing cost reduction, including improved production innovation and efficiency at our newest factories and lower logistics costs, and focus on operating leverage will continue to benefit us in relation to our competitors, while our new products will help enable future growth.

As our production increases, we must work constantly to similarly increase vehicle delivery capability so that it does not become a bottleneck on our total deliveries. We are also committed to reducing the percentage of vehicles delivered in the third month of each quarter, which will help to reduce the cost per vehicle. As we expand our manufacturing operations globally, we will also have to continue to increase and staff our delivery, servicing and charging infrastructure accordingly, maintain our vehicle reliability and optimize our Supercharger locations to ensure cost effectiveness and customer satisfaction. In particular, as other automotive manufacturers have announced their adoption of the North American Charging Standard (“NACS”) and agreements with us to utilize our Superchargers, we must correspondingly expand our network in order to ensure adequate availability to meet customer demands. We also remain focused on continued enhancements of the capability and efficiency of our servicing operations.
Energy Generation and Storage Demand, Production and Deployment
The long-term success of this business is dependent upon increasing margins through greater volumes. We continue to increase the production of our energy storage products to meet high levels of demand, including the construction of a new Megafactory in Shanghai and the ongoing ramp at our Megafactory in Lathrop, California. For Megapack, energy storage deployments can vary meaningfully quarter to quarter depending on the timing of specific project milestones. We remain committed to growing our retrofit solar energy business by offering a low-cost and simplified online ordering experience. In addition, we continue to seek to improve our installation capabilities and price efficiencies for Solar Roof. As these product lines grow, we will have to maintain adequate battery cell supply for our energy storage products and ensure the availability of qualified personnel, particularly skilled electricians, to support the ramp of Solar Roof.
Cash Flow and Capital Expenditure Trends
Our capital expenditures are typically difficult to project beyond the short-term given the number and breadth of our core projects at any given time, and may further be impacted by uncertainties in future global market conditions. We are simultaneously ramping new products, building or ramping manufacturing facilities on three continents, piloting the development and manufacture of new battery cell technologies, expanding our Supercharger network and investing in autonomy and other artificial intelligence enabled training and products, and the pace of our capital spend may vary depending on overall priority among projects, the pace at which we meet milestones, production adjustments to and among our various products, increased capital efficiencies and the addition of new projects. Owing and subject to the foregoing as well as the pipeline of announced projects under development, all other continuing infrastructure growth and varying levels of inflation, we currently expect our capital expenditures to exceed $10.00 billion in 2024 and be between $8.00 to $10.00 billion in each of the following two fiscal years.
Our business has been consistently generating cash flow from operations in excess of our level of capital spend, and with better working capital management resulting in shorter days sales outstanding than days payable outstanding, our sales growth is also generally facilitating positive cash generation. We have and will continue to utilize such cash flows, among other things, to do more vertical integration, expand our product roadmap and provide financing options to our customers. At the same time, we are likely to see heightened levels of capital expenditures during certain periods depending on the specific pace of our capital-intensive projects and other potential variables such as rising material prices and increases in supply chain and labor expenses resulting from changes in global trade conditions and labor availability. Overall, we expect our ability to be self-funding to continue as long as macroeconomic factors support current trends in our sales.
"""

# %% [markdown]
# Given this context, we will now implement self-reflection to answer the following user question.

# %%
question = "How are the company's efforts to increase capacity going to impact their bottomline?"

# %% [markdown]
# # Solution Implementation

# %% [markdown]
# ## Generator

# %% [markdown]
# We begin by first setting up the generator using a standard RAG prompt (using `LangChain` abstractions). The prompt instructs the LLM to answer questions using only the context information. Since this is the reflection pattern, the LLM is also instructed to expect user feedback and revise answers accounting for the feedback.
#
# The system message and the prompt for the generator can be composed like so:

# %%
prompt = ChatPromptTemplate.from_messages([(
        "system",
        "You are an expert analyst at a financial services firm who answers user queries on annual reports."
        " User input will have the context required by you to answer user questions."
        " This context will begin with the word: ###Context."
        " The context contains documents relevant to the user query."
        " User questions will begin with the word: ###Question."
        " Please answer user questions only using the context provided in the input."
        " If the user provides critique, respond with a revised version of your previous attempts.",
    ),MessagesPlaceholder(variable_name="messages"),])

# %% [markdown]
# The above prompt has a placeholder for messages that will be presented by the user (`HumanMessage`) and includes the context and the question like so:

# %%
request = HumanMessage(
    content=f"""
    ###Context:
    {financial_statement_context_data}
    ---
    ###Question:
    {question}
    """
)

# %% [markdown]
# Now we can compose the generator as an amalgamation of the system message and the LLM like so.
#
# We now invoke the generator using the user message composed earlier.

# %%
generator = prompt | llm_groq

response = generator.invoke({'messages': [request]})
print(response.content)
# Out:
# The company's efforts to increase capacity are expected to have a positive impact on their bottom line.
#
# Here's why:
#
# * **Increased production:**  Expanding manufacturing capacity will allow them to produce more vehicles and energy products, leading to higher revenue.
# * **Cost reductions:** By increasing production volume and implementing cost-saving measures like vertical integration and localizing supply chains, they aim to decrease production costs per unit.
# * **Operating leverage:** As production and sales increase, fixed costs are spread over a larger number of units, improving profitability.
#
#
# The company also mentions that their strategy includes "cost reduction efforts, cost innovation strategies, and additional localized procurement and manufacturing" which are key to vehicle affordability and have allowed them to competitively price their vehicles.

# %% [markdown]
# The above output is the first attempt of the generator. Let us now assemble a reflector that will look at the output from the generator and provide pointed feedback to improve the answer.

# %% [markdown]
# ## Reflector

# %% [markdown]
# We now implement a reflector using a system message that asks the LLM (the same LLM since this is self-reflection) to review the answer.
#
# To invoke the reflector, we pass in the response that is received from the generator in the previous section.

# %%
reflection_prompt = ChatPromptTemplate.from_messages([(
    "system",
    "You are an expert financial analyst rating an answer to a question. Generate critique and recommendations for the user's submission."
    " Provide detailed recommendations, including factual grounding, logic, coherence, etc.",
), MessagesPlaceholder(variable_name="messages"),])

reflector = reflection_prompt | llm_groq

reflection = reflector.invoke({'messages': [request, HumanMessage(content=response.content)]})
print(reflection.content)
# Out:
# This is a good start, but the answer could be strengthened by incorporating more specific details and addressing potential challenges. Here's a more detailed critique and recommendations:
#
# **Strengths:**
#
# * You accurately identify the main drivers of a positive impact on the bottom line: increased production, cost reductions, and operating leverage.
# * You mention the company's focus on cost reduction strategies, highlighting their commitment to improving profitability.
#
# **Areas for Improvement:**
#
# * **Quantify the impact:**  While stating that increased production will lead to higher revenue is accurate, providing some concrete figures or estimates would strengthen the analysis. For example, if they aim to increase production by X% and the average selling price remains constant, this implies a revenue increase of Y%.
# * **Address potential challenges:**
#
#     * **Ramp-up costs:** Expanding capacity requires significant upfront investments. While the long-term goal is cost reduction, the initial ramp-up phase can be costly. Mentioning this and how the company plans to manage these costs would add nuance.
#     * **Demand uncertainty:**  Even with increased capacity,  demand for their products may not grow at the same rate. Overproduction could lead to inventory build-up and decreased profitability. Discuss any measures the company is taking to mitigate this risk (e.g., pre-orders, flexible production planning).
#     * **Competition:**  The automotive industry is becoming increasingly competitive.  New entrants and established players are also expanding capacity.  How will the company maintain its market share and pricing power in this environment?
# * **Specificity:**
#
#     * **"Cost reduction efforts"** is a vague term. Provide specific examples of these efforts, such as streamlining production processes, sourcing cheaper materials, or negotiating better deals with suppliers.
#     * **"Localized procurement and manufacturing"**  –  Explain how this strategy will lead to cost reductions and what specific steps are being taken to implement it.
#
# **Revised Answer:**
#
# The company's efforts to increase capacity are expected to have a positive impact on their bottom line through several key drivers.
#
# * **Higher Revenue:** Increased production volumes will directly translate to higher revenue. For example, if they can increase vehicle production by 20% while maintaining current average selling prices, this could result in a $19.34 billion increase in revenue (based on 2023 figures).
# * **Cost Reductions:** The company is actively pursuing cost-saving measures, including [mention specific examples like streamlining production processes, sourcing cheaper materials, or negotiating better deals with suppliers]. Additionally, their focus on localized procurement and manufacturing aims to reduce transportation costs and reliance on global supply chains. This should lead to a decrease in production costs per unit, improving profitability.
# * **Operating Leverage:** As production and sales scale, fixed costs will be spread over a larger number of units, resulting in improved operating leverage and increased profitability.
#
# However, it's crucial to acknowledge potential challenges:
#
# * **Ramp-up Costs:**  Expanding capacity requires significant upfront investments. The company needs to manage these costs effectively during the initial ramp-up phase to ensure a positive impact on profitability.
# * **Demand Uncertainty:**  While the company is optimistic about future demand, the automotive market is cyclical and subject to economic fluctuations. They need to closely monitor demand trends and adjust production plans accordingly to avoid overproduction and inventory build-up.
# * **Increased Competition:**  The electric vehicle market is becoming increasingly competitive. The company needs to maintain its competitive edge through continuous innovation, cost leadership, and effective marketing strategies.
#
# By carefully managing these challenges and effectively executing their capacity expansion plans, the company is well-positioned to achieve significant long-term profitability growth.

# %% [markdown]
# As indicated in the above output, the reflector provided clear guidance on the strengths and recommends specific changes.
#
# Now that we have built and tested the generator and reflector, we can now compose an execution graph that has these as key nodes and execution bounces back and forth between them.

# %% [markdown]
# ## Self-Reflection as an Execution Graph

# %% [markdown]
# We now build an execution graph with control passed between the generator and the reflector. In `LangGraph`, this execution graph can be crystallized by passing the state of the graph between the generator and reflector defined as nodes in the graph.

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]


async def generation_node(state: State) -> State:
    return {"messages": [await generator.ainvoke(state["messages"])]}


async def reflection_node(state: State) -> State:
    # Other messages we need to adjust
    cls_map = {"ai": HumanMessage, "human": AIMessage}
    # First message is the original user request. We hold it the same for all nodes
    translated = [state["messages"][0]] + [
        cls_map[msg.type](content=msg.content) for msg in state["messages"][1:]
    ]
    res = await reflector.ainvoke(translated)
    # We treat the output of this as human feedback for the generator
    return {"messages": [HumanMessage(content=res.content)]}

# %% [markdown]
# The above code defines two asynchronous functions `generation_node` and `reflection_node` that encapsulate the same logic that we tested out in the previous sections.
#
# The `generation_node` simply invokes the LLM with the context and the user question. The `reflection_node` takes its output (AI output) and presents it as user feedback back to the generator. This necessitates a swap of `AIMessage` and `HumanMessage`.

# %% [markdown]
# Now that both the nodes are defined, we need to stitch them up into an execution graph. This is done by instatiating a `StateGraph` and adding the generator and reflector nodes to it liek so:

# %%
builder = StateGraph(State)
builder.add_node("generator", generation_node)
builder.add_node("reflector", reflection_node)
builder.add_edge(START, "generator")

# %% [markdown]
# As the above code indicates, we add two nodes - generator & reflector. Then we add an edge between the `START` node and the generator.
#
# Instead of directly connecting the generator and the reflector with an edge, we implement a conditional edge that is triggered till three iterations of feedback are passes between the reflector and the generator.
#
# The code below implements this logic.

# %%
def should_continue(state: State):
    if len(state["messages"]) > 6: return END  # End after 3 iterations
    return "reflector"

builder.add_conditional_edges("generator", should_continue)
builder.add_edge("reflector", "generator")

# %% [markdown]
# With this graph now wired up, we can compile it and inspect its structure. Note that in `LangGraph` execution graphs need to be compiled before use.

# %%
graph = builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# We can now execute the above graph like so:

# %%
async for event in graph.astream(
    {
        "messages": [
            HumanMessage(
                content=f"""
                ###Context:
                {financial_statement_context_data}
                ---
                ###Question:
                {question}
                """
            )
        ]
    }
):
    print(event)
    print("---")
# Out:
# {'generator': {'messages': [AIMessage(content='The company states that increasing vehicle production, capacity, and delivery capabilities is a key focus area for the coming years. This is expected to lead to higher revenue growth as they can deliver more vehicles.  \n\nThey also plan to reduce costs through improved production innovation and efficiency at their newest factories and lower logistics costs. These cost reductions, combined with increased production volumes, should improve their operating margins and positively impact the bottom line.  \n\n\nHowever, the company acknowledges that this ramp-up  is subject to uncertainties, including supply chain constraints, labor shortages, and the successful implementation of new technologies. These factors could potentially impact their ability to increase production and realize the expected cost savings, thus affecting the bottom line. \n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 145, 'prompt_tokens': 2146, 'total_tokens': 2291, 'completion_time': 0.263636364, 'prompt_time': 0.057929856, 'queue_time': 1.829541796, 'total_time': 0.32156622}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--7c16393a-b242-45e2-a308-05398d9d6be8-0', usage_metadata={'input_tokens': 2146, 'output_tokens': 145, 'total_tokens': 2291})]}}
# ---
# {'reflector': {'messages': [HumanMessage(content="That's a good start! You've correctly identified the key points about increased capacity leading to higher revenues and potential cost reductions. \n\nHere's a more detailed critique and recommendations to strengthen your analysis:\n\n**Strengths:**\n\n* **Identified key drivers:** You clearly state the company's focus on increasing production capacity, delivery capabilities, and cost reduction as drivers of bottom-line impact.\n* **Recognized revenue growth potential:** You accurately point out that higher production volumes should lead to increased revenue.\n\n**Areas for Improvement:**\n\n* **Quantify the impact:**  While you mention revenue growth and cost reduction,  provide more concrete examples and, whenever possible, quantify the potential impact. For example:\n    *  The company mentions a goal to improve production efficiency at new factories. Can you find any data or estimates on the potential cost savings from these improvements?\n    *  What is the company's historical production growth rate? How does the projected increase in capacity compare to this history?\n* **Address operational challenges:** You touch on supply chain constraints and labor shortages but could elaborate further. \n    *  How significant are these challenges for the company currently?\n    *  What steps is the company taking to mitigate these risks? \n    *  Are there any historical examples of similar challenges impacting their production and profitability?\n* **Consider competitive landscape:** The company mentions increased competition in the electric vehicle market. \n    * How might this competition affect their pricing power and market share?\n    *  Are there any specific competitors that pose a significant threat to their bottom line?\n* **Factor in macroeconomic conditions:** The company acknowledges the impact of macroeconomic factors like inflation and interest rates. \n    *  How might these factors influence consumer demand for their vehicles?\n    *  What are the potential risks and opportunities presented by these macroeconomic trends?\n* **Analyze long-term sustainability:** \n    *  How does the company's focus on renewable energy and sustainability align with long-term profitability goals?\n    *  Are there any potential costs or benefits associated with this sustainability focus?\n\n**Recommendations:**\n\n* **Dig deeper into financial data:** Analyze historical financial statements (income statement, balance sheet, cash flow statement) to identify trends and potential risks.\n* **Research industry reports and analyses:** Look for reports from reputable sources that provide insights into the electric vehicle market, supply chain challenges, and competitive landscape.\n* **Consider expert opinions:**  Read articles and interviews with industry analysts and experts to gain a broader perspective on the company's prospects.\n\n\nBy incorporating these recommendations, you can develop a more comprehensive and insightful analysis of how the company's capacity expansion efforts are likely to impact their bottom line. \n", additional_kwargs={}, response_metadata={}, id='8742b61a-be64-4272-8304-275c3e371a83')]}}
# ---
# {'generator': {'messages': [AIMessage(content='You are right, my previous response lacked depth and specific examples. \n\nHere\'s a revised analysis incorporating your valuable feedback:\n\nThe company\'s plans to increase vehicle production capacity, delivery capabilities, and reduce costs are expected to have a significant impact on their bottom line.  \n\n**Revenue Growth:**\n\n* The company delivered 1,808,581 vehicles in 2023.  With a stated focus on increasing production, they aim to deliver even more vehicles in the coming years.  \n* While the exact revenue growth projection isn\'t provided, we can see a strong correlation between increased production and higher revenues. Their 2023 revenue of $96.77 billion represents a significant increase compared to the prior year, driven by higher production volumes. \n\n**Cost Reduction:**\n\n* The company highlights "improved production innovation and efficiency at our newest factories" as a key driver of cost reduction. \n* They also aim to reduce logistics costs.  \n* However, specific quantifiable data on the potential cost savings from these initiatives are not provided in the text.  \n\n**Operational Challenges:**\n\n* The company acknowledges the challenges of supply chain constraints, labor shortages, and the successful implementation of new technologies. \n*  They mention "pre-planned shutdowns for upgrades at various factories" in 2023, highlighting the potential for operational disruptions during the ramp-up phase.\n*  The company doesn\'t provide specific data on the severity of these challenges or their mitigation strategies.\n\n**Competitive Landscape:**\n\n* The company recognizes increased competition in the electric vehicle market, with other manufacturers adopting the North American Charging Standard ("NACS") and using their Supercharger network.  \n* This competition could put downward pressure on pricing and market share. \n\n**Macroeconomic Factors:**\n\n*  Inflationary pressures and rising interest rates are acknowledged as potential headwinds, impacting consumer affordability and vehicle financing.\n\n**Long-Term Sustainability:**\n\n* The company\'s focus on renewable energy and sustainability is highlighted as a core mission.\n* The text doesn\'t explicitly link this focus to profitability, but it suggests that it\'s a long-term strategic driver.\n\n\n\n**Conclusion:**\n\nWhile the company\'s capacity expansion plans have the potential to drive significant revenue growth and cost reductions, they also face several operational, competitive, and macroeconomic challenges. A more detailed analysis would require access to financial data, industry reports, and expert opinions to assess the company\'s ability to overcome these challenges and achieve its long-term profitability goals.  \n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 534, 'prompt_tokens': 2864, 'total_tokens': 3398, 'completion_time': 0.970909091, 'prompt_time': 0.068572368, 'queue_time': 2.067531101, 'total_time': 1.039481459}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--a61a98f3-a299-4020-9c32-bc664b1601d7-0', usage_metadata={'input_tokens': 2864, 'output_tokens': 534, 'total_tokens': 3398})]}}
# ---
# {'reflector': {'messages': [HumanMessage(content='This is a much-improved analysis! You\'ve incorporated my feedback effectively, digging deeper into the financials, acknowledging challenges, and considering the broader context. Here are a few final suggestions:\n\n**1.  Connect the dots:** While you\'ve identified several factors, try to weave them together more explicitly to show the potential interplay between them. \n\n* For example,  how might supply chain constraints exacerbate the challenges of meeting increased production targets?\n* Could cost reductions offset some of the potential impact of increased competition? \n* How might the company\'s sustainability focus influence consumer demand and, consequently, profitability?\n\n**2.  Look for quantitative data:**  Even if the company doesn\'t provide specific figures on cost savings or revenue projections, look for clues in their language and past performance. \n\n*  Phrases like "significantly increased" or "rapidly" suggest a degree of magnitude. \n*  Historical data on production growth, cost reductions, or market share changes can help you make more informed estimations.\n\n**3.  Offer a nuanced perspective:**  Avoid presenting a purely optimistic or pessimistic view. Acknowledge the uncertainties and potential risks while highlighting the company\'s strengths and opportunities.  \n\n* For example,  you could say: "While the company faces significant challenges in its capacity expansion plans, its strong brand recognition, technological innovation, and focus on sustainability position it well to navigate these headwinds and achieve long-term profitability."\n\n**Overall, your revised analysis is much stronger. By incorporating these final recommendations, you can create a more comprehensive and insightful evaluation of the company\'s bottom-line prospects.** \n\n\n', additional_kwargs={}, response_metadata={}, id='f63c40c1-9426-4c8f-a326-63ad7a89018f')]}}
# ---
# {'generator': {'messages': [AIMessage(content='You\'re right, weaving the various factors together and offering a more nuanced perspective will strengthen the analysis. Here\'s a revised version incorporating your excellent suggestions:\n\nThe company\'s ambitious plans to significantly increase vehicle production capacity and reduce costs hold the promise of substantial bottom-line improvements. However, the path to achieving these goals is fraught with challenges and uncertainties. \n\n**Revenue Growth Potential:**  \n\n* The company\'s 2023 revenue surge, driven by a nearly 16% increase in production compared to 2022, demonstrates their strong potential for revenue growth. \n*  Their focus on expanding production capacity and delivery capabilities suggests a continued upward trajectory. \n* However,  this growth will be heavily reliant on their ability to navigate the complexities of the global supply chain and labor market.\n\n**Cost Reduction Efforts:**\n\n* The company highlights improvements in production innovation and efficiency at their newest factories as key drivers of cost reduction. \n* This, coupled with efforts to lower logistics costs, could significantly enhance profitability. \n*  However,  specific details about the magnitude of these potential savings are lacking in the provided text.\n\n**Navigating Operational Challenges:** \n\n* Supply chain constraints and labor shortages pose a significant risk to the company\'s ability to meet its ambitious production targets. \n* For example,  the text mentions "pre-planned shutdowns for upgrades at various factories" in 2023, highlighting the potential for operational disruptions during the ramp-up phase. \n* Successfully mitigating these challenges will be crucial for realizing the full potential of their capacity expansion plans.\n\n**Competitive Landscape:**\n\n*  The electric vehicle market is becoming increasingly competitive, with other manufacturers adopting the North American Charging Standard ("NACS") and utilizing the company\'s Supercharger network. \n* This increased competition could put downward pressure on pricing and market share. \n*  However,  the company\'s strong brand recognition and technological innovation may help them maintain a competitive edge.\n\n**Macroeconomic Headwinds:**\n\n*  Inflationary pressures and rising interest rates pose a threat to consumer affordability and vehicle financing, potentially impacting demand for the company\'s products. \n* The company\'s ability to adapt to these macroeconomic headwinds through strategic pricing adjustments and financial flexibility will be crucial for maintaining profitability.\n\n**Sustainability as a Differentiator:**\n\n\n\n* The company\'s commitment to sustainability could be a significant differentiator in the marketplace, attracting environmentally conscious consumers and potentially commanding premium pricing. \n*  However,  the long-term financial impact of this focus will depend on the company\'s ability to balance environmental goals with profitability.\n\n **Conclusion:**\n\nThe company\'s capacity expansion plans present both significant opportunities and considerable challenges. While their strong brand, technological innovation, and focus on sustainability provide a solid foundation for future growth, they must carefully navigate supply chain constraints, competitive pressures, and macroeconomic headwinds to achieve their bottom-line objectives.  A successful outcome will depend on their ability to execute their plans effectively, adapt to changing market conditions, and demonstrate a clear path to long-term profitability. \n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 648, 'prompt_tokens': 3742, 'total_tokens': 4390, 'completion_time': 1.178181818, 'prompt_time': 0.099167919, 'queue_time': 1.638215902, 'total_time': 1.277349737}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'service_tier': 'on_demand', 'finish_reason ...
# ---
# {'reflector': {'messages': [HumanMessage(content='This is excellent! You\'ve woven the various factors together seamlessly, creating a compelling and nuanced analysis that acknowledges both the opportunities and risks. \n\nHere are a few minor suggestions to further strengthen your conclusion:\n\n* **Offer a balanced outlook:** While you mention both opportunities and risks, consider adding a brief, balanced statement about your overall assessment of the company\'s prospects. For example, you could say: "While challenges exist, the company\'s strategic focus and market position suggest a high likelihood of success in achieving its ambitious bottom-line goals." \n* **Highlight key areas for further research:**  Mention any specific areas where more information would be helpful in forming a more definitive conclusion. For example, "Further analysis of the company\'s supply chain strategy and cost reduction initiatives would provide a clearer picture of their ability to overcome operational challenges and achieve projected cost savings."\n\nOverall, this is a very strong analysis. You\'ve demonstrated a good understanding of the company\'s business model, key drivers, and potential risks, and you\'ve presented your findings in a clear and concise manner.\n\n\n', additional_kwargs={}, response_metadata={}, id='4cf63fa1-a59c-4506-a824-4f2722ce05a2')]}}
# ---
# {'generator': {'messages': [AIMessage(content="Thank you for the continued feedback!  Here's the conclusion with the suggested refinements:\n\n**Conclusion:**\n\nThe company's capacity expansion plans present both significant opportunities and considerable challenges. While challenges exist in navigating supply chain constraints, competitive pressures, and macroeconomic headwinds, the company's strong brand, technological innovation, and focus on sustainability provide a solid foundation for future growth.  While challenges exist, the company's strategic focus and market position suggest a high likelihood of success in achieving its ambitious bottom-line goals. Further analysis of the company's supply chain strategy and cost reduction initiatives would provide a clearer picture of their ability to overcome operational challenges and achieve projected cost savings. \n\n\n\n", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 143, 'prompt_tokens': 4622, 'total_tokens': 4765, 'completion_time': 0.26, 'prompt_time': 0.122255253, 'queue_time': 1.734818398, 'total_time': 0.382255253}, 'model_name': 'gemma2-9b-it', 'system_fingerprint': 'fp_10c08bf97d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--720ca1c5-fde3-4880-a0fd-cd1e8136ff89-0', usage_metadata={'input_tokens': 4622, 'output_tokens': 143, 'total_tokens': 4765})]}}
# ---

# %% [markdown]
# The final answer after 3 rounds of reflection can be extracted like so.

# %%
print(event['generator']['messages'][0].content)
# Out:
# Thank you for the continued feedback!  Here's the conclusion with the suggested refinements:
#
# **Conclusion:**
#
# The company's capacity expansion plans present both significant opportunities and considerable challenges. While challenges exist in navigating supply chain constraints, competitive pressures, and macroeconomic headwinds, the company's strong brand, technological innovation, and focus on sustainability provide a solid foundation for future growth.  While challenges exist, the company's strategic focus and market position suggest a high likelihood of success in achieving its ambitious bottom-line goals. Further analysis of the company's supply chain strategy and cost reduction initiatives would provide a clearer picture of their ability to overcome operational challenges and achieve projected cost savings.
